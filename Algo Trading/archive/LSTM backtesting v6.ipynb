# %% [markdown]
# Changes from v2:
#
# 1. ATR is calculated inside strategy s.t. it can be used to calculate take profit and stop loss
# 2. implemented PCA to reduce dimension

# %% [markdown]
# ## Import Library

# %%
from humpback import *

from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers, models

from backtesting import Backtest, Strategy

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Defining Functions

# %% [markdown]
# Functions in this section would be moved to humpback.py after testing for tidiness

# %% [markdown]
# https://keras.io/examples/timeseries/timeseries_traffic_forecasting/

# %% [markdown]
# ## Defining Model

# %%
class LSTM_stack(layers.Layer):
    """stacks of LSTM with dropout, follwed by dense layer"""

    def __init__(
        self,
        dropout_rate: float = 0.2
        ):
        super().__init__()

        self.lstm_1 = layers.LSTM(
            units=50,
            return_sequences=True,
            )

        self.lstm_2 = layers.LSTM(
            units=50,
            return_sequences=True,
            )

        self.lstm_3 = layers.LSTM(
            units=50,
            return_sequences=False,
            )

        self.dense_1 = layers.Dense(
            units=1
            )

        self.dropout_1 = layers.Dropout(dropout_rate)

    def call(self, inputs):
        x = self.lstm_1(inputs)
        x = self.dropout_1(x)
        x = self.lstm_2(inputs)
        x = self.dropout_1(x)
        x = self.lstm_3(inputs)
        x = self.dropout_1(x)
        return self.dense_1(x)

# %% [markdown]
# ## Defining Strategy

# %%
class MyStr(Strategy):
    # Variables:
    # train_size = 0.7
    buy_threshold  =  .005
    sell_threshold = -.005

    # params
    N_train = 12200
    input_sequence_length = 20
    PCA_components = 6

    def init(self):
        # Declare indicators you will use in the strategy:
        self.getData(train_length=self.N_train, PCA_components=self.PCA_components)
        self.model_init(input_sequence_length=self.input_sequence_length, PCA_components=self.PCA_components)
        self.model_train()

        data_return = getReturn(self.data.df, 'Close')
        X = featureGeneration(data_return)
        X, _ = getXy(X, 'Return')
        X = self.pca.transform(self.X_scaler.transform(X.to_numpy()))

        X_dataset = keras.utils.timeseries_dataset_from_array(
            X,
            None,
            sequence_length=self.input_sequence_length,
            shuffle=False)

        prediction = self.model.predict(X_dataset)

        self.prediction = self.I(lambda: np.repeat(np.nan, len(self.data)), name='prediction')
        self.prediction[-len(prediction):] = prediction.flatten()

    def next(self):
        if len(self.data) < self.N_train:
            return

        # data_return = getReturn(self.data.df, 'Close')
        # X = featureGeneration(data_return)
        # X, _ = getXy(X, 'Return')
        # X = self.pca.transform(self.X_scaler.transform(X.to_numpy()))

        # X_dataset = keras.utils.timeseries_dataset_from_array(
        #     X[-(self.input_sequence_length+1):],
        #     None,
        #     sequence_length=self.input_sequence_length,
        #     shuffle=False)

        # prediction = self.model.predict(X_dataset)
        
        atr_tp_sl = atr(self.data.df)

        if self.prediction[-1] > self.buy_threshold and not self.position.is_long:
            tp = self.data.Close[-1] + 2 * atr_tp_sl[-1]
            sl = self.data.Close[-1] - 2 * atr_tp_sl[-1]
            self.buy(size=.2, tp=tp, sl=sl)

        if self.prediction[-1] < self.sell_threshold and not self.position.is_short:
            tp = self.data.Close[-1] - 2 * atr_tp_sl[-1]
            sl = self.data.Close[-1] + 2 * atr_tp_sl[-1]
            self.sell(size=.2, tp=tp, sl=sl)

########################################

    def getData(self, train_length: int, PCA_components: int):
        data_return = getReturn(self.data.df, 'Close')
        data_feature = featureGeneration(data_return)
        X_data_df, y_data_df = getXy(data_feature.iloc[:train_length,], 'Return')

        train_size = 0.6
        val_size   = 0.4
        test_size  = 0
        
        X_train_array, X_val_array, _, self.X_scaler, self.pca = preprocess(X_data_df, train_size, val_size, test_size, apply_PCA=True, PCA_components=PCA_components)
        y_train_array, y_val_array, _, self.y_scaler = preprocess(y_data_df, train_size, val_size, test_size, apply_PCA=False)

        self.train_dataset = keras.utils.timeseries_dataset_from_array(
            X_train_array,
            y_train_array,
            sequence_length=self.input_sequence_length,
            shuffle=False)

        self.val_dataset = keras.utils.timeseries_dataset_from_array(
            X_val_array,
            y_val_array,
            sequence_length=self.input_sequence_length,
            shuffle=False) 

        # self.test_dataset = keras.utils.timeseries_dataset_from_array(
        #     X_test_array,
        #     None,
        #     sequence_length=input_sequence_length,
        #     shuffle=False) 

    def model_init(self, input_sequence_length: int, PCA_components: int):
        inputs  = keras.Input((
            input_sequence_length,
            PCA_components))
        outputs = LSTM_stack()(inputs)
        self.model   = keras.Model(inputs, outputs)

        optimizer = keras.optimizers.Adam()
        loss      = keras.losses.MeanSquaredError()

        self.model.compile(optimizer=optimizer,loss=loss)

    def model_train(self):
        self.model.fit(
            self.train_dataset,
            epochs=20,
            validation_data=self.val_dataset)

# %%
class WalkForwardStr(MyStr):
    def next(self):
        # Skip the cold start period with too few values available
        if len(self.data) < len(self.y_train):
            return
            
        if len(self.data) % 500:
            return super().next()

        # Retrain on last N_TRAIN values
        self.getData()
        self.model_init()

        # Now that the model is fitted, 
        # proceed the same as in MLTrainOnceStrategy
        super().next()

# %% [markdown]
# ## Parameters

# %% [markdown]
# This section contains all the parameters.

# %%
# This chunk specifies the data

symbol = 'BTCUSDT'

# %% [markdown]
# ## Obtain data

# %% [markdown]
# This section outputs training and testing data for the use of the following sections.

# %%
data_raw_df = pd.read_csv(f'Binance Data/{symbol}.csv', index_col='index')
data_raw_df = data_raw_df.set_index(pd.DatetimeIndex(pd.to_datetime(data_raw_df.index)))

# %% [markdown]
# ## Backtesting

# %%
bt    = Backtest(data_raw_df, MyStr, cash = 1000000, commission=0.00075, margin=.05)
stats = bt.run()

# %% [markdown]
# ## Results

# %%
bt.plot()
# Out:
# Row(id='2678', ...)

# %%
# stats.tail()

# %%
# stats['_equity_curve']

# %% [markdown]
# ## Ad hoc

# %%
# %%time

stats_skopt, heatmap, optimize_result = bt.optimize(
    buy_threshold =[ 0.001,  0.1],      # Note: For method="skopt", we
    sell_threshold=[-0.001, -0.1],      # only need interval end-points
    maximize='Equity Final [$]',
    method='skopt',
    max_tries=200,
    random_state=0,
    return_heatmap=True,
    return_optimization=True)
# Out:
# Epoch 1/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - loss: 0.5519 - val_loss: 0.4158
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.4944 - val_loss: 0.3965
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4759 - val_loss: 0.3854
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4743 - val_loss: 0.3824
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4677 - val_loss: 0.3817
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4634 - val_loss: 0.3812
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.4685 - val_loss: 0.3797
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4572 - val_loss: 0.3786
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4598 - val_loss: 0.3772
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.4490 - val_loss: 0.3763
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4520 - val_loss: 0.3765
# Epoch 12/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.4497 - val_loss: 0.3761
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.4482 - val_loss: 0.3746
# Epoch 14/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.4396 - val_loss: 0.3741
# Epoch 15/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.
# Epoch 2/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.4819 - val_loss: 0.3856
# Epoch 3/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.4706 - val_loss: 0.3848
# Epoch 4/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4711 - val_loss: 0.3829
# Epoch 5/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4714 - val_loss: 0.3811
# Epoch 6/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.4520 - val_loss: 0.3801
# Epoch 7/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.4517 - val_loss: 0.3787
# Epoch 8/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.4536 - val_loss: 0.3776
# Epoch 9/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.4438 - val_loss: 0.3767
# Epoch 10/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.4415 - val_loss: 0.3758
# Epoch 11/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4439 - val_loss: 0.3747
# Epoch 12/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4421 - val_loss: 0.3735
# Epoch 13/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.4390 - val_loss: 0.3732
# Epoch 14/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.4362 - val_loss: 0.3728
# Epoch 15/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4437 - val_loss: 0.3724
# Epoch 16/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.4388 - val_loss: 0.3707
# Epoch 17/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4348 - val_loss: 0.3710
# Epoch 18/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.4350 - val_loss: 0.3679
# Epoch 19/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4278 - val_loss: 0.3692
# Epoch 20/20
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.4222 - val_loss: 0.3680
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:1
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/backtesting/backtesting.py:1542, in Backtest.optimize(self, maximize, method, max_tries, constraint, return_heatmap, return_optimization, random_state, **kwargs)
#    1540     output = _optimize_grid()
#    1541 elif method == 'skopt':
# -> 1542     output = _optimize_skopt()
#    1543 else:
#    1544     raise ValueError(f"Method should be 'grid' or 'skopt', not {method!r}")
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/backtesting/backtesting.py:1508, in Backtest.optimize.<locals>._optimize_skopt()
#    1504 with warnings.catch_warnings():
#    1505     warnings.filterwarnings(
#    1506         'ignore', 'The objective has been evaluated at this point before.')
# -> 1508     res = forest_minimize(
#    1509         func=objective_function,
#    1510         dimensions=dimensions,
#    1511         n_calls=max_tries,
#    1512         base_estimator=ExtraTreesRegressor(n_estimators=20, min_samples_leaf=2),
#    1513         acq_func='LCB',
#    1514         kappa=3,
#    1515         n_initial_points=min(max_tries, 20 + 3 * len(kwargs)),
#    1516         initial_point_generator='lhs',  # 'sobel' requires n_initial_points ~ 2**N
#    1517         callback=DeltaXStopper(9e-7),
#    1518         random_state=random_state)
#    1520 stats = self.run(**dict(zip(kwargs.keys(), res.x)))
#    1521 output = [stats]
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/skopt/optimizer/forest.py:203, in forest_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, acq_func, initial_point_generator, x0, y0, random_state, verbose, callback, n_points, xi, kappa, n_jobs, model_queue_size, space_constraint)
#       6 def forest_minimize(
#       7     func,
#       8     dimensions,
#    (...)
#      25     space_constraint=None,
#      26 ):
#      27     """Sequential optimisation using decision trees.
#      28
#      29     A tree based regression model is used to model the expensive to evaluate
#    (...)
#     201         :class:`skopt.dummy_minimize`, :class:`skopt.gbrt_minimize`
#     202     """
# --> 203     return base_minimize(
#     204         func,
#     205         dimensions,
#     206         base_estimator,
#     207         n_calls=n_calls,
#     208         n_points=n_points,
#     209         n_random_starts=n_random_starts,
#     210         n_initial_points=n_initial_points,
#     211         initial_point_generator=initial_point_generator,
#     212         x0=x0,
#     213         y0=y0,
#     214         random_state=random_state,
#     215         n_jobs=n_jobs,
#     216         acq_func=acq_func,
#     217         xi=xi,
#     218         kappa=kappa,
#     219         verbose=verbose,
#     220         callback=callback,
#     221         acq_optimizer="sampling",
#     222         space_constraint=space_constraint,
#     223         model_queue_size=model_queue_size,
#     224     )
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/skopt/optimizer/base.py:332, in base_minimize(func, dimensions, base_estimator, n_calls, n_random_starts, n_initial_points, initial_point_generator, acq_func, acq_optimizer, x0, y0, random_state, verbose, callback, n_points, n_restarts_optimizer, xi, kappa, n_jobs, model_queue_size, space_constraint)
#     330 for _ in range(n_calls):
#     331     next_x = optimizer.ask()
# --> 332     next_y = func(next_x)
#     333     result = optimizer.tell(next_x, next_y)
#     334     result.specs = specs
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/skopt/utils.py:779, in use_named_args.<locals>.decorator.<locals>.wrapper(x)
#     776 arg_dict = {dim.name: value for dim, value in zip(dimensions, x)}
#     778 # Call the wrapped objective function with the named arguments.
# --> 779 objective_value = func(**arg_dict)
#     781 return objective_value
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/backtesting/backtesting.py:1498, in Backtest.optimize.<locals>._optimize_skopt.<locals>.objective_function(**params)
#    1496 if not constraint(AttrDict(params)):
#    1497     return INVALID
# -> 1498 res = memoized_run(tuple(params.items()))
#    1499 value = -maximize(res)
#    1500 if np.isnan(value):
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/backtesting/backtesting.py:1485, in Backtest.optimize.<locals>._optimize_skopt.<locals>.<lambda>(tup)
#    1480         dimensions.append(Categorical(values.tolist(), name=key, transform='onehot'))
#    1482 # Avoid recomputing re-evaluations:
#    1483 # "The objective has been evaluated at this point before."
#    1484 # https://github.com/scikit-optimize/scikit-optimize/issues/302
# -> 1485 memoized_run = lru_cache()(lambda tup: self.run(**dict(tup)))
#    1487 # np.inf/np.nan breaks sklearn, np.finfo(float).max breaks skopt.plots.plot_objective
#    1488 INVALID = 1e300
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/backtesting/backtesting.py:1220, in Backtest.run(self, **kwargs)
#    1217         break
#    1219     # Next tick, a moment before bar close
# -> 1220     strategy.next()
#    1221 else:
#    1222     # Close any remaining open trades so they produce some stats
#    1223     for trade in broker.trades:
#
# Cell In[15], line 51, in MyStr.next(self)
#      36     return
#      38 # data_return = getReturn(self.data.df, 'Close')
#      39 # X = featureGeneration(data_return)
#      40 # X, _ = getXy(X, 'Return')
#    (...)
#      48
#      49 # prediction = self.model.predict(X_dataset)
# ---> 51 atr_tp_sl = atr(self.data.df)
#      53 if self.prediction[-1] > self.buy_threshold and not self.position.is_long:
#      54     tp = self.data.Close[-1] + 2 * atr_tp_sl[-1]
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/humpback.py:74, in atr(data)
#      73 def atr(data):
# ---> 74     return ta.volatility.AverageTrueRange(data.loc[:, 'High'], data.loc[:, 'Low'], data.loc[:, 'Close']).average_true_range()
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/ta/volatility.py:44, in AverageTrueRange.__init__(self, high, low, close, window, fillna)
#      42 self._window = window
#      43 self._fillna = fillna
# ---> 44 self._run()
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/ta/volatility.py:48, in AverageTrueRange._run(self)
#      46 def _run(self):
#      47     close_shift = self._close.shift(1)
# ---> 48     true_range = self._true_range(self._high, self._low, close_shift)
#      49     atr = np.zeros(len(self._close))
#      50     atr[self._window - 1] = true_range[0 : self._window].mean()
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/ta/utils.py:45, in IndicatorMixin._true_range(high, low, prev_close)
#      43 tr2 = (high - prev_close).abs()
#      44 tr3 = (low - prev_close).abs()
# ---> 45 true_range = pd.DataFrame(data={"tr1": tr1, "tr2": tr2, "tr3": tr3}).max(axis=1)
#      46 return true_range
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/pandas/core/frame.py:11656, in DataFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   11648 @doc(make_doc("max", ndim=2))
#   11649 def max(
#   11650     self,
#    (...)
#   11654     **kwargs,
#   11655 ):
# > 11656     result = super().max(axis, skipna, numeric_only, **kwargs)
#   11657     if isinstance(result, Series):
#   11658         result = result.__finalize__(self, method="max")
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/pandas/core/generic.py:12404, in NDFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   12397 def max(
#   12398     self,
#   12399     axis: Axis | None = 0,
#    (...)
#   12402     **kwargs,
#   12403 ):
# > 12404     return self._stat_function(
#   12405         "max",
#   12406         nanops.nanmax,
#   12407         axis,
#   12408         skipna,
#   12409         numeric_only,
#   12410         **kwargs,
#   12411     )
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/pandas/core/generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/pandas/core/frame.py:11566, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11564 if out_dtype is not None and out.dtype != "boolean":
#   11565     out = out.astype(out_dtype)
# > 11566 elif (df._mgr.get_dtypes() == object).any() and name not in ["any", "all"]:
#   11567     out = out.astype(object)
#   11568 elif len(self) == 0 and out.dtype == object and name in ("sum", "prod"):
#   11569     # Even if we are object dtype, follow numpy and return
#   11570     #  float64, see test_apply_funcs_over_empty
#
# File ~/Documents/Alvin/GitHub/alvinlui99/Algo Trading/.venv/lib/python3.12/site-packages/numpy/core/_methods.py:55, in _any(a, axis, dtype, out, keepdims, where)
#      51 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#      52           initial=_NoValue, where=True):
#      53     return umr_prod(a, axis, dtype, out, keepdims, initial, where)
# ---> 55 def _any(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      56     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      57     if where is True:
#      58         return umr_any(a, axis, dtype, out, keepdims)
#
# KeyboardInterrupt:
