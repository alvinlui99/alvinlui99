# %% [markdown]
# Key features in v8:
#
# 1. Long Short
#
# Reference
# Binance Margin Bracket
# https://www.binance.com/en/futures/trading-rules/quarterly/leverage-margin

# %% [markdown]
# ## Import Library

# %%
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import ta

from tensorflow import keras
from tensorflow.keras import layers, models

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Out:
# 2024-08-29 13:09:11.772967: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Defining Functions

# %% [markdown]
# ### Feature Engineering

# %%
def addSMA(data, sma_start: int, sma_end: int, sma_step: int):
    sma_range = range(sma_start, sma_end, sma_step)

    for window in sma_range:
        # SMA/Close
        # relative value of SMA to closing price
        data.loc[:,f"SMA_{window}"] = ta.trend.SMAIndicator(data.Close, window=window).sma_indicator() / data.Close

    for i in range(len(sma_range)):
        for j in range(i+1, len(sma_range)):
            # (SMA_1 - SMA_2) / Close
            data.loc[:,f"SMA_DELTA_{sma_range[i]}_{sma_range[j]}"] = data.loc[:,f"SMA_{sma_range[i]}"] - data.loc[:,f"SMA_{sma_range[j]}"]

    return data

# %%
def addEMA(data, ema_start: int, ema_end: int, ema_step: int):
    ema_range = range(ema_start, ema_end, ema_step)

    for window in ema_range:
        # EMA/Close
        # relative value of EMA to closing price
        data.loc[:,f"EMA_{window}"] = ta.trend.EMAIndicator(data.Close, window=window).ema_indicator() / data.Close

    for i in range(len(ema_range)):
        for j in range(i+1, len(ema_range)):
            # (EMA_1 - EMA_2) / Close
            data.loc[:,f"EMA_DELTA_{ema_range[i]}_{ema_range[j]}"] = data.loc[:,f"EMA_{ema_range[i]}"] - data.loc[:,f"EMA_{ema_range[j]}"]

    return data

# %%
def feature_generation(
    data,
    sma_start: int = 20,
    sma_end  : int = 100,
    sma_step : int = 20,
    ema_start: int = 20,
    ema_end  : int = 100,
    ema_step : int = 20
    ):
    """
    Input
    --------
    X: pd.DataFrame


    Output
    --------
    X: pd.DataFrame
    """
    close = data.Close

    # SMA
    data = addSMA(data=data, sma_start=sma_start, sma_end=sma_end, sma_step=sma_step)

    # EMA
    data = addEMA(data=data, ema_start=ema_start, ema_end=ema_end, ema_step=ema_step)

    # RSI
    data["RSI"] = ta.momentum.RSIIndicator(data.Close).rsi()
  
    # MACD
    data["MACD"] = ta.trend.MACD(data.Close).macd()

    # ATR
    data["ATR"] = ta.volatility.AverageTrueRange(data.High, data.Low, data.Close).average_true_range()

    # BollingerBands
    upper = ta.volatility.BollingerBands(data.Close).bollinger_hband()
    lower = ta.volatility.BollingerBands(data.Close).bollinger_lband()

    data["BB_upper"] = (upper - close) / close
    data["BB_lower"] = (lower - close) / close
    data["BB_width"] = (upper - lower) / close

    # Garman Klass Volatility
    data["garman_klass_vol"] = ((np.log(data.High)-np.log(data.Low))**2)/2-(2*np.log(2)-1)*((np.log(data.Close)-np.log(data.Open))**2)

    return data

# %%
def preprocess(data,
               PCA_components = 8):
  # Feature generation
  data_features = feature_generation(data)

  # Feature
  remove_columns = ["Open",
                    "High",
                    "Low",
                    "Close"]
  features = data_features.drop(remove_columns, axis=1).dropna()

  # normalize
  scaler = StandardScaler()
  features = pd.DataFrame(
    scaler.fit_transform(features),
    index=features.index,
    columns=features.columns)

  # PCA
  pca = PCA(n_components=PCA_components)
  features = pd.DataFrame(
    pca.fit_transform(features),
    index=features.index)
  
  return features

# %%
def create_LSTM_input(data, time_steps=10):
    num_samples = data.shape[0] - time_steps + 1
    X = np.array([data[i:i+time_steps] for i in range(num_samples)])
    return X

# %% [markdown]
# ## Defining Model

# %%
class LSTM_stack(layers.Layer):
    """stacks of LSTM with dropout, followed by dense layer"""

    def __init__(
        self,
        dropout_rate: float = 0.2
        ):
        super().__init__()

        self.lstm_1 = layers.LSTM(
            units=50,
            return_sequences=True,
            )

        self.lstm_2 = layers.LSTM(
            units=50,
            return_sequences=True,
            )

        self.lstm_3 = layers.LSTM(
            units=50,
            return_sequences=False,
            )

        self.dense_1 = layers.Dense(
            units=1
            )

        self.dropout_1 = layers.Dropout(dropout_rate)

    def call(self, inputs):
        x = self.lstm_1(inputs)
        x = self.dropout_1(x)
        x = self.lstm_2(inputs)
        x = self.dropout_1(x)
        x = self.lstm_3(inputs)
        x = self.dropout_1(x)
        return self.dense_1(x)

# %% [markdown]
# ## Defining Trading Environment

# %%
class Coin:
    def __init__(self, symbol, ohlcv):
        self.symbol = symbol
        self.ohlcv = ohlcv
        self.logret = self.calculate_logret()
        self.trading_history = []  # List to store trading history
        self.volatility = self.calculate_volatility()
        self.features = preprocess(
            pd.concat([
                self.ohlcv,
                self.logret,
                self.volatility],
                axis=1))
        self.y = self.logret.shift(-1)

    def calculate_logret(self):
        return pd.DataFrame(
            np.log((self.ohlcv.Close / self.ohlcv.Close.shift(1)))).rename(columns={"Close": "logret"})

    def calculate_volatility(self):
        return pd.DataFrame(
            self.logret.rolling(window=14).std()).rename(columns={"logret": "vol"})

# %%
class Market:
    def __init__(
        self,
        cash = 10000):
        self.coins = {}  # Dictionary to store coins
        self.init_cash = cash
        self.cash = self.init_cash  # Initial cash balance
        self.assets = {}  # Dictionary to store quantity of each asset
        self.prices = pd.DataFrame()

        self.margin_rate = 0.004


    def add_coin(self, coin):
        self.coins[coin.symbol] = coin
        self.assets[coin.symbol] = 0  # Initialize asset quantity to 0

        close = pd.DataFrame(coin.ohlcv.Close).rename(columns={"Close": coin.symbol})
        self.prices = pd.concat([self.prices, close], axis=1)
        
        self.coins[coin.symbol].trading_history = []
        self.coins[coin.symbol].position = "Closed"

        self.coins[coin.symbol].entry_cost = 0

    def reset(self):
        self.cash = self.init_cash
        for symbol in self.coins:
            self.coins[symbol].trading_history = []
            self.assets[symbol] = 0  # Initialize asset quantity to 0
            self.coins[symbol].position = "Closed"
            self.coins[symbol].entry_cost = 0

    def trade(self, symbol, action, quantity, price, time):
        if action == "long":
            self.market_long(symbol, quantity, price, time)

        if action == "short":
            self.market_short(symbol, quantity, price, time)

        elif action == "close":
            if self.coins[symbol].position != "Closed":
                if self.coins[symbol].position == "Long":
                    self.market_long_close(symbol, quantity, price, time)
                if self.coins[symbol].position == "Short":
                    self.market_short_close(symbol, quantity, price, time)

    def market_long(self, symbol, quantity, price, time):        
        available_margin = self.cash
        maintenance_margin = quantity * price * self.margin_rate
        margin_balance = available_margin
        margin_ratio = maintenance_margin / margin_balance

        if margin_ratio < 1:
            self.assets[symbol] += quantity
            self.coins[symbol].trading_history.append(
                {
                    "action": "long",
                    "quantity": quantity,
                    "price": price,
                    "time": time
                })
            self.coins[symbol].entry_cost = quantity * price
            self.coins[symbol].position = "Long"

    def market_long_close(self, symbol, quantity, price, time):
        notional_value = qty * price

        self.cash += notional_value - self.coins[symbol].entry_cost

        self.assets[symbol] -= quantity
        self.coins[symbol].trading_history.append(
            {
                "action": "close",
                "quantity": quantity,
                "price": price,
                "time": time
            })
        self.coins[symbol].entry_cost = 0
        self.coins[symbol].position = "Closed"

    def market_short(self, symbol, quantity, price, time):
        self.assets[symbol] -= quantity
        self.coins[symbol].trading_history.append(
            {
                "action": "short",
                "quantity": quantity,
                "price": price,
                "time": time
            })
        self.coins[symbol].entry_cost = quantity * price
        self.coins[symbol].position = "Short"

    def market_short_close(self, symbol, quantity, price, time):
        notional_value = qty * price

        self.cash += notional_value - self.coins[symbol].entry_cost

        self.assets[symbol] += quantity
        self.coins[symbol].trading_history.append(
            {
                "action": "close",
                "quantity": quantity,
                "price": price,
                "time": time
            })
        self.coins[symbol].entry_cost = 0
        self.coins[symbol].position = "Closed"

    def get_margin_ratio(self, time):
        maintenance_margin = 0
        margin_balance = self.cash
        for symbol in self.coins:
            qty = self.assets[symbol]
            price = self.prices.loc[time, symbol]
            entry_cost = self.coins[symbol].entry_cost

            notional_value = qty * price

            maintenance_margin += notional_value * self.margin_rate
            margin_balance += notional_value - entry_cost
        
        margin_ratio = maintenance_margin / margin_balance

        return margin_ratio

# %% [markdown]
# ## Parameters

# %% [markdown]
# This section contains all the parameters.

# %%
symbols = [
    "ADAUSDT",
    "BNBUSDT",
    "BTCUSDT",
    "EOSUSDT",
    "ETHUSDT",
    "LTCUSDT",
    "NEOUSDT",
    "QTUMUSDT",
    "XRPUSDT"
    ]

interval = "15m"

# %% [markdown]
# ## Training the Model

# %% [markdown]
# This section outputs training and testing data for the use of the following sections.

# %% [markdown]
# ### Creating the market for training the model

# %%
market_train = Market()
for symbol in symbols:
    data_train = pd.read_csv(f"Binance Data/Training/{interval}/{symbol}.csv", index_col="index")
    data_train = data_train.set_index(pd.DatetimeIndex(pd.to_datetime(data_train.index)))
    coin = Coin(symbol, data_train)
    market_train.add_coin(coin)

# %%
market_val = Market()
for symbol in symbols:
    data_val = pd.read_csv(f"Binance Data/Validation/{interval}/{symbol}.csv", index_col="index")
    data_val = data_val.set_index(pd.DatetimeIndex(pd.to_datetime(data_val.index)))
    coin = Coin(symbol, data_val)
    market_val.add_coin(coin)

# %%
market_test = Market()
for symbol in symbols:
    data_test = pd.read_csv(f"Binance Data/Testing/{interval}/{symbol}.csv", index_col="index")
    data_test = data_test.set_index(pd.DatetimeIndex(pd.to_datetime(data_test.index)))
    coin = Coin(symbol, data_test)
    market_test.add_coin(coin)

# %% [markdown]
# ### Initializing the model

# %%
inputs = keras.Input((10, 8)) # Hard-coded timestep and number of features
outputs = LSTM_stack()(inputs)
model = keras.Model(inputs, outputs)
optimizer = keras.optimizers.Adam()
loss      = keras.losses.MeanSquaredError()
model.compile(optimizer=optimizer,loss=loss)

# %% [markdown]
# ### Training the model

# %%
for symbol in symbols:
    X_train = create_LSTM_input(market_train.coins[symbol].features)[:-1]
    y_train = market_train.coins[symbol].logret[-X_train.shape[0]:]

    X_val = create_LSTM_input(market_val.coins[symbol].features)[:-1]
    y_val = market_val.coins[symbol].logret[-X_val.shape[0]:]
    model.fit(
        X_train, y_train,
        epochs = 50,
        validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - loss: 0.0109 - val_loss: 6.4538e-05
# Epoch 2/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.1758e-04 - val_loss: 4.2570e-05
# Epoch 3/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 6.7245e-05 - val_loss: 3.4651e-05
# Epoch 4/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 6.2386e-05 - val_loss: 4.1959e-05
# Epoch 5/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.5856e-05 - val_loss: 2.9931e-05
# Epoch 6/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.7560e-05 - val_loss: 3.0085e-05
# Epoch 7/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.4512e-05 - val_loss: 2.9447e-05
# Epoch 8/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.4602e-05 - val_loss: 3.1289e-05
# Epoch 9/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.3505e-05 - val_loss: 2.8649e-05
# Epoch 10/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 5.4163e-05 - val_loss: 3.1647e-05
# Epoch 11/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.4783e-05 - val_loss: 3.2142e-05
# Epoch 12/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.5100e-05 - val_loss: 2.9665e-05
# Epoch 13/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.2009e-05 - val_loss: 2.8693e-05
# Epoch 14/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.6352e-05 - val_loss: 2.8797e-05
# Epoch 15/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.4017e-05 - val_loss: 2.8331e-05
# Epoch 16/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.2087e-05 - val_loss: 2.8324e-05
# Epoch 17/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 5.1234e-05 - val_loss: 2.8446e-05
# Epoch 18/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.2905e-05 - val_loss: 2.9948e-05
# Epoch 19/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.1680e-05 - val_loss: 3.0174e-05
# Epoch 20/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.2215e-05 - val_loss: 2.9003e-05
# Epoch 21/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.2589e-05 - val_loss: 2.9984e-05
# Epoch 22/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.4097e-05 - val_loss: 2.8662e-05
# Epoch 23/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.1781e-05 - val_loss: 2.9109e-05
# Epoch 24/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.3198e-05 - val_loss: 2.8984e-05
# Epoch 25/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.2347e-05 - val_loss: 2.9082e-05
# Epoch 26/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.3352e-05 - val_loss: 2.8343e-05
# Epoch 27/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.2600e-05 - val_loss: 2.9196e-05
# Epoch 28/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.2771e-05 - val_loss: 2.8966e-05
# Epoch 29/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.2072e-05 - val_loss: 2.9931e-05
# Epoch 30/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.2799e-05 - val_loss: 2.8528e-05
# Epoch 31/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.3275e-05 - val_loss: 2.9229e-05
# Epoch 32/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.2938e-05 - val_loss: 3.0411e-05
# Epoch 33/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.1529e-05 - val_loss: 2.8965e-05
# Epoch 34/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.2739e-05 - val_loss: 2.8639e-05
# Epoch 35/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.1823e-05 - val_loss: 2.8995e-05
# Epoch 36/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.0568e-05 - val_loss: 3.1105e-05
# Epoch 37/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.0193e-05 - val_loss: 2.9117e-05
# Epoch 38/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.1686e-05 - val_loss: 3.0421e-05
# Epoch 39/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.1501e-05 - val_loss: 2.9434e-05
# Epoch 40/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.9941e-05 - val_loss: 2.9469e-05
# Epoch 41/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.1025e-05 - val_loss: 3.0032e-05
# Epoch 42/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.2615e-05 - val_loss: 2.9474e-05
# Epoch 43/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.2068e-05 - val_loss: 3.0652e-05
# Epoch 44/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.9832e-05 - val_loss: 2.9306e-05
# Epoch 45/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.0918e-05 - val_loss: 2.8926e-05
# Epoch 46/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.0311e-05 - val_loss: 3.0065e-05
# Epoch 47/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.1647e-05 - val_loss: 3.1956e-05
# Epoch 48/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 5.1217e-05 - val_loss: 2.9253e-05
# Epoch 49/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.9740e-05 - val_loss: 3.0060e-05
# Epoch 50/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 5.0730e-05 - val_loss: 3.0672e-05
# Epoch 1/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.3304e-05 - val_loss: 1.6267e-05
# Epoch 2/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0236e-05 - val_loss: 1.7898e-05
# Epoch 3/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0122e-05 - val_loss: 1.7115e-05
# Epoch 4/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.2081e-05 - val_loss: 1.6456e-05
# Epoch 5/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.1579e-05 - val_loss: 1.6397e-05
# Epoch 6/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.8971e-05 - val_loss: 1.6830e-05
# Epoch 7/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.9738e-05 - val_loss: 1.6063e-05
# Epoch 8/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.1035e-05 - val_loss: 1.7537e-05
# Epoch 9/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0258e-05 - val_loss: 1.6622e-05
# Epoch 10/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0315e-05 - val_loss: 1.6735e-05
# Epoch 11/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0289e-05 - val_loss: 1.6788e-05
# Epoch 12/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.8595e-05 - val_loss: 1.7366e-05
# Epoch 13/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.9963e-05 - val_loss: 1.6410e-05
# Epoch 14/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0973e-05 - val_loss: 1.9329e-05
# Epoch 15/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0439e-05 - val_loss: 1.6334e-05
# Epoch 16/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.2578e-05 - val_loss: 1.6926e-05
# Epoch 17/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0562e-05 - val_loss: 1.7491e-05
# Epoch 18/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0533e-05 - val_loss: 1.6927e-05
# Epoch 19/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.1836e-05 - val_loss: 1.7112e-05
# Epoch 20/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.2353e-05 - val_loss: 1.7406e-05
# Epoch 21/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0875e-05 - val_loss: 1.7699e-05
# Epoch 22/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.1303e-05 - val_loss: 1.6543e-05
# Epoch 23/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.1196e-05 - val_loss: 1.6698e-05
# Epoch 24/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.1730e-05 - val_loss: 1.6599e-05
# Epoch 25/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.3323e-05 - val_loss: 1.7157e-05
# Epoch 26/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0286e-05 - val_loss: 1.7712e-05
# Epoch 27/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.9547e-05 - val_loss: 1.8005e-05
# Epoch 28/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0313e-05 - val_loss: 1.8106e-05
# Epoch 29/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.1161e-05 - val_loss: 1.8729e-05
# Epoch 30/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.1247e-05 - val_loss: 1.7551e-05
# Epoch 31/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.9975e-05 - val_loss: 1.8323e-05
# Epoch 32/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.8975e-05 - val_loss: 1.7926e-05
# Epoch 33/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0044e-05 - val_loss: 1.7108e-05
# Epoch 34/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.1333e-05 - val_loss: 1.8180e-05
# Epoch 35/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0661e-05 - val_loss: 1.7845e-05
# Epoch 36/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.9678e-05 - val_loss: 1.7813e-05
# Epoch 37/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.9328e-05 - val_loss: 1.7352e-05
# Epoch 38/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0286e-05 - val_loss: 1.8519e-05
# Epoch 39/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.9156e-05 - val_loss: 1.7903e-05
# Epoch 40/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.9462e-05 - val_loss: 1.7799e-05
# Epoch 41/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.8794e-05 - val_loss: 1.9194e-05
# Epoch 42/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.7952e-05 - val_loss: 1.8709e-05
# Epoch 43/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.9062e-05 - val_loss: 1.9400e-05
# Epoch 44/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.8572e-05 - val_loss: 1.8960e-05
# Epoch 45/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.9729e-05 - val_loss: 1.7828e-05
# Epoch 46/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.8400e-05 - val_loss: 1.7368e-05
# Epoch 47/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.0222e-05 - val_loss: 1.9082e-05
# Epoch 48/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.9394e-05 - val_loss: 1.9030e-05
# Epoch 49/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.8695e-05 - val_loss: 2.3903e-05
# Epoch 50/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 3.8867e-05 - val_loss: 1.8406e-05
# Epoch 1/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 2.2900e-05 - val_loss: 1.2832e-05
# Epoch 2/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 2.0787e-05 - val_loss: 1.2539e-05
# Epoch 3/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.9665e-05 - val_loss: 1.3230e-05
# Epoch 4/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 2.0358e-05 - val_loss: 1.3111e-05
# Epoch 5/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 2.0052e-05 - val_loss: 1.4682e-05
# Epoch 6/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.9878e-05 - val_loss: 1.3390e-05
# Epoch 7/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9227e-05 - val_loss: 1.4639e-05
# Epoch 8/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.8825e-05 - val_loss: 1.3059e-05
# Epoch 9/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9142e-05 - val_loss: 1.2853e-05
# Epoch 10/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 2.0211e-05 - val_loss: 1.3794e-05
# Epoch 11/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9301e-05 - val_loss: 1.6700e-05
# Epoch 12/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.8673e-05 - val_loss: 1.5300e-05
# Epoch 13/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.8533e-05 - val_loss: 1.7058e-05
# Epoch 14/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9035e-05 - val_loss: 1.5155e-05
# Epoch 15/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9906e-05 - val_loss: 1.7143e-05
# Epoch 16/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9499e-05 - val_loss: 1.6361e-05
# Epoch 17/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9265e-05 - val_loss: 1.4902e-05
# Epoch 18/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.0107e-05 - val_loss: 1.5915e-05
# Epoch 19/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.0067e-05 - val_loss: 1.5008e-05
# Epoch 20/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9912e-05 - val_loss: 1.5722e-05
# Epoch 21/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.0327e-05 - val_loss: 1.6062e-05
# Epoch 22/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9136e-05 - val_loss: 1.6785e-05
# Epoch 23/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9690e-05 - val_loss: 1.5847e-05
# Epoch 24/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.0102e-05 - val_loss: 1.5222e-05
# Epoch 25/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9374e-05 - val_loss: 2.0449e-05
# Epoch 26/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.0499e-05 - val_loss: 1.8815e-05
# Epoch 27/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9445e-05 - val_loss: 1.8246e-05
# Epoch 28/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.8781e-05 - val_loss: 1.5889e-05
# Epoch 29/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9684e-05 - val_loss: 1.7347e-05
# Epoch 30/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9189e-05 - val_loss: 1.6528e-05
# Epoch 31/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9078e-05 - val_loss: 1.8056e-05
# Epoch 32/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.8782e-05 - val_loss: 1.6855e-05
# Epoch 33/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9068e-05 - val_loss: 2.2790e-05
# Epoch 34/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.8802e-05 - val_loss: 1.6818e-05
# Epoch 35/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.0033e-05 - val_loss: 1.7966e-05
# Epoch 36/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9910e-05 - val_loss: 1.7487e-05
# Epoch 37/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9423e-05 - val_loss: 1.6972e-05
# Epoch 38/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.8846e-05 - val_loss: 1.7829e-05
# Epoch 39/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9829e-05 - val_loss: 1.7008e-05
# Epoch 40/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.8428e-05 - val_loss: 1.9685e-05
# Epoch 41/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.8944e-05 - val_loss: 1.5440e-05
# Epoch 42/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9125e-05 - val_loss: 1.6434e-05
# Epoch 43/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.8569e-05 - val_loss: 1.8219e-05
# Epoch 44/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.7899e-05 - val_loss: 2.0060e-05
# Epoch 45/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9542e-05 - val_loss: 1.5474e-05
# Epoch 46/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.8363e-05 - val_loss: 1.6026e-05
# Epoch 47/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.8520e-05 - val_loss: 1.6656e-05
# Epoch 48/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9232e-05 - val_loss: 1.7641e-05
# Epoch 49/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.9509e-05 - val_loss: 1.4107e-05
# Epoch 50/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.8548e-05 - val_loss: 1.8824e-05
# Epoch 1/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.1787e-05 - val_loss: 2.8172e-05
# Epoch 2/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7824e-05 - val_loss: 2.7834e-05
# Epoch 3/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8351e-05 - val_loss: 2.6447e-05
# Epoch 4/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8007e-05 - val_loss: 2.7337e-05
# Epoch 5/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.4770e-05 - val_loss: 2.8602e-05
# Epoch 6/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5582e-05 - val_loss: 2.7936e-05
# Epoch 7/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7277e-05 - val_loss: 2.8278e-05
# Epoch 8/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5041e-05 - val_loss: 2.7621e-05
# Epoch 9/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.6809e-05 - val_loss: 2.8534e-05
# Epoch 10/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.6735e-05 - val_loss: 2.7255e-05
# Epoch 11/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7078e-05 - val_loss: 2.8085e-05
# Epoch 12/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5091e-05 - val_loss: 2.7204e-05
# Epoch 13/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8644e-05 - val_loss: 2.8502e-05
# Epoch 14/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7801e-05 - val_loss: 2.7923e-05
# Epoch 15/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5307e-05 - val_loss: 2.8950e-05
# Epoch 16/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.4573e-05 - val_loss: 2.8295e-05
# Epoch 17/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7423e-05 - val_loss: 2.8360e-05
# Epoch 18/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.6930e-05 - val_loss: 3.0703e-05
# Epoch 19/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5856e-05 - val_loss: 2.7708e-05
# Epoch 20/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.9281e-05 - val_loss: 3.1318e-05
# Epoch 21/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.6234e-05 - val_loss: 2.8389e-05
# Epoch 22/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.4584e-05 - val_loss: 2.9183e-05
# Epoch 23/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5609e-05 - val_loss: 2.8291e-05
# Epoch 24/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.4215e-05 - val_loss: 2.8327e-05
# Epoch 25/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7521e-05 - val_loss: 2.9261e-05
# Epoch 26/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5410e-05 - val_loss: 2.8879e-05
# Epoch 27/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5231e-05 - val_loss: 2.9133e-05
# Epoch 28/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8410e-05 - val_loss: 2.9317e-05
# Epoch 29/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7710e-05 - val_loss: 3.1505e-05
# Epoch 30/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5668e-05 - val_loss: 2.9137e-05
# Epoch 31/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5599e-05 - val_loss: 2.9027e-05
# Epoch 32/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5554e-05 - val_loss: 3.2218e-05
# Epoch 33/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5539e-05 - val_loss: 2.8760e-05
# Epoch 34/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.6431e-05 - val_loss: 3.2974e-05
# Epoch 35/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5755e-05 - val_loss: 3.0646e-05
# Epoch 36/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5072e-05 - val_loss: 3.3313e-05
# Epoch 37/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5267e-05 - val_loss: 2.9837e-05
# Epoch 38/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.4121e-05 - val_loss: 3.1689e-05
# Epoch 39/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5096e-05 - val_loss: 3.0396e-05
# Epoch 40/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7064e-05 - val_loss: 2.9781e-05
# Epoch 41/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5090e-05 - val_loss: 3.0215e-05
# Epoch 42/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5914e-05 - val_loss: 3.1975e-05
# Epoch 43/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.6399e-05 - val_loss: 3.3001e-05
# Epoch 44/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.4602e-05 - val_loss: 3.2689e-05
# Epoch 45/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.3566e-05 - val_loss: 3.2917e-05
# Epoch 46/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.3545e-05 - val_loss: 3.1745e-05
# Epoch 47/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7505e-05 - val_loss: 3.3812e-05
# Epoch 48/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.3220e-05 - val_loss: 3.3491e-05
# Epoch 49/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.6481e-05 - val_loss: 3.3145e-05
# Epoch 50/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.6252e-05 - val_loss: 3.1197e-05
# Epoch 1/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.3630e-05 - val_loss: 2.2030e-05
# Epoch 2/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.3993e-05 - val_loss: 2.2454e-05
# Epoch 3/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.1653e-05 - val_loss: 2.2258e-05
# Epoch 4/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.1167e-05 - val_loss: 2.5082e-05
# Epoch 5/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.1237e-05 - val_loss: 2.2804e-05
# Epoch 6/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0577e-05 - val_loss: 2.3622e-05
# Epoch 7/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0856e-05 - val_loss: 2.3810e-05
# Epoch 8/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.2784e-05 - val_loss: 2.5830e-05
# Epoch 9/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.2607e-05 - val_loss: 2.3528e-05
# Epoch 10/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.1287e-05 - val_loss: 2.3970e-05
# Epoch 11/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.1411e-05 - val_loss: 2.2535e-05
# Epoch 12/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0223e-05 - val_loss: 2.3068e-05
# Epoch 13/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.1788e-05 - val_loss: 2.3226e-05
# Epoch 14/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.1191e-05 - val_loss: 2.2629e-05
# Epoch 15/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.2218e-05 - val_loss: 2.3172e-05
# Epoch 16/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0282e-05 - val_loss: 2.3554e-05
# Epoch 17/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.1543e-05 - val_loss: 2.3879e-05
# Epoch 18/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0234e-05 - val_loss: 2.4455e-05
# Epoch 19/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0405e-05 - val_loss: 2.4491e-05
# Epoch 20/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0080e-05 - val_loss: 2.4717e-05
# Epoch 21/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0457e-05 - val_loss: 2.4384e-05
# Epoch 22/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0467e-05 - val_loss: 2.4797e-05
# Epoch 23/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0397e-05 - val_loss: 2.3978e-05
# Epoch 24/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 3.2004e-05 - val_loss: 2.5026e-05
# Epoch 25/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0954e-05 - val_loss: 2.5902e-05
# Epoch 26/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0792e-05 - val_loss: 2.5408e-05
# Epoch 27/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.1430e-05 - val_loss: 2.5305e-05
# Epoch 28/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0664e-05 - val_loss: 2.4909e-05
# Epoch 29/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0656e-05 - val_loss: 2.5657e-05
# Epoch 30/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.1404e-05 - val_loss: 2.5941e-05
# Epoch 31/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.9856e-05 - val_loss: 2.8766e-05
# Epoch 32/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0433e-05 - val_loss: 2.8696e-05
# Epoch 33/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.9195e-05 - val_loss: 2.6475e-05
# Epoch 34/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.9930e-05 - val_loss: 2.6111e-05
# Epoch 35/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 3.0335e-05 - val_loss: 2.7199e-05
# Epoch 36/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0582e-05 - val_loss: 2.6880e-05
# Epoch 37/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0943e-05 - val_loss: 3.0099e-05
# Epoch 38/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.9138e-05 - val_loss: 2.7003e-05
# Epoch 39/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0072e-05 - val_loss: 2.7597e-05
# Epoch 40/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.9872e-05 - val_loss: 3.1105e-05
# Epoch 41/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.8740e-05 - val_loss: 2.8732e-05
# Epoch 42/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.9510e-05 - val_loss: 2.9318e-05
# Epoch 43/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.9242e-05 - val_loss: 2.8289e-05
# Epoch 44/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.9903e-05 - val_loss: 3.1649e-05
# Epoch 45/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.9955e-05 - val_loss: 3.0725e-05
# Epoch 46/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 2.9717e-05 - val_loss: 3.2515e-05
# Epoch 47/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0176e-05 - val_loss: 3.0663e-05
# Epoch 48/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.1092e-05 - val_loss: 3.1650e-05
# Epoch 49/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.0560e-05 - val_loss: 2.9248e-05
# Epoch 50/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.1099e-05 - val_loss: 3.0685e-05
# Epoch 1/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.6974e-05 - val_loss: 2.6735e-05
# Epoch 2/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.3717e-05 - val_loss: 2.6413e-05
# Epoch 3/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.4303e-05 - val_loss: 2.5934e-05
# Epoch 4/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.4289e-05 - val_loss: 2.6997e-05
# Epoch 5/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.2330e-05 - val_loss: 2.5837e-05
# Epoch 6/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5236e-05 - val_loss: 2.6848e-05
# Epoch 7/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.4069e-05 - val_loss: 2.8022e-05
# Epoch 8/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.4082e-05 - val_loss: 3.0244e-05
# Epoch 9/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.9026e-05 - val_loss: 2.7832e-05
# Epoch 10/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.3074e-05 - val_loss: 2.8387e-05
# Epoch 11/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.0519e-05 - val_loss: 3.1183e-05
# Epoch 12/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5986e-05 - val_loss: 2.9759e-05
# Epoch 13/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.2249e-05 - val_loss: 2.7240e-05
# Epoch 14/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.1170e-05 - val_loss: 3.0729e-05
# Epoch 15/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.1326e-05 - val_loss: 2.9227e-05
# Epoch 16/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.1839e-05 - val_loss: 2.8751e-05
# Epoch 17/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.0192e-05 - val_loss: 3.0919e-05
# Epoch 18/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7338e-05 - val_loss: 3.0736e-05
# Epoch 19/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.1139e-05 - val_loss: 2.9430e-05
# Epoch 20/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.2629e-05 - val_loss: 2.8859e-05
# Epoch 21/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.0182e-05 - val_loss: 3.2423e-05
# Epoch 22/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.0601e-05 - val_loss: 3.1607e-05
# Epoch 23/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.2858e-05 - val_loss: 3.1311e-05
# Epoch 24/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.1756e-05 - val_loss: 3.1890e-05
# Epoch 25/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.2581e-05 - val_loss: 3.2231e-05
# Epoch 26/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.1441e-05 - val_loss: 3.1772e-05
# Epoch 27/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.2167e-05 - val_loss: 3.0829e-05
# Epoch 28/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.2092e-05 - val_loss: 3.0162e-05
# Epoch 29/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.1677e-05 - val_loss: 3.3829e-05
# Epoch 30/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.1655e-05 - val_loss: 3.1207e-05
# Epoch 31/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.2011e-05 - val_loss: 3.1914e-05
# Epoch 32/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.1793e-05 - val_loss: 3.7113e-05
# Epoch 33/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.9853e-05 - val_loss: 3.2717e-05
# Epoch 34/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.2965e-05 - val_loss: 3.4529e-05
# Epoch 35/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5310e-05 - val_loss: 3.6726e-05
# Epoch 36/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.3658e-05 - val_loss: 3.4898e-05
# Epoch 37/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.1102e-05 - val_loss: 3.2289e-05
# Epoch 38/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.2151e-05 - val_loss: 3.4117e-05
# Epoch 39/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.0666e-05 - val_loss: 3.0461e-05
# Epoch 40/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.3010e-05 - val_loss: 3.0933e-05
# Epoch 41/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.2405e-05 - val_loss: 2.9626e-05
# Epoch 42/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.1511e-05 - val_loss: 3.2812e-05
# Epoch 43/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.1822e-05 - val_loss: 3.2489e-05
# Epoch 44/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.1161e-05 - val_loss: 3.3606e-05
# Epoch 45/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.2001e-05 - val_loss: 3.3052e-05
# Epoch 46/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.0983e-05 - val_loss: 3.4968e-05
# Epoch 47/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.5488e-05 - val_loss: 3.4095e-05
# Epoch 48/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.2079e-05 - val_loss: 3.2020e-05
# Epoch 49/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.1406e-05 - val_loss: 3.3102e-05
# Epoch 50/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 3.9792e-05 - val_loss: 3.0587e-05
# Epoch 1/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.2566e-05 - val_loss: 2.8648e-05
# Epoch 2/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.1727e-05 - val_loss: 3.0518e-05
# Epoch 3/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.0751e-05 - val_loss: 3.0249e-05
# Epoch 4/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.0980e-05 - val_loss: 2.9913e-05
# Epoch 5/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.0696e-05 - val_loss: 3.0175e-05
# Epoch 6/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8104e-05 - val_loss: 3.1832e-05
# Epoch 7/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.0620e-05 - val_loss: 3.0595e-05
# Epoch 8/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.1995e-05 - val_loss: 3.0902e-05
# Epoch 9/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.0792e-05 - val_loss: 3.1089e-05
# Epoch 10/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.0505e-05 - val_loss: 3.2679e-05
# Epoch 11/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.0109e-05 - val_loss: 3.3426e-05
# Epoch 12/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.9092e-05 - val_loss: 3.1790e-05
# Epoch 13/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.0712e-05 - val_loss: 3.2704e-05
# Epoch 14/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8706e-05 - val_loss: 3.2624e-05
# Epoch 15/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.9357e-05 - val_loss: 3.2567e-05
# Epoch 16/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.0350e-05 - val_loss: 3.6982e-05
# Epoch 17/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8080e-05 - val_loss: 3.6752e-05
# Epoch 18/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.5194e-05 - val_loss: 3.3508e-05
# Epoch 19/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8794e-05 - val_loss: 3.2126e-05
# Epoch 20/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.9404e-05 - val_loss: 3.4324e-05
# Epoch 21/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8095e-05 - val_loss: 3.6991e-05
# Epoch 22/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7226e-05 - val_loss: 3.4920e-05
# Epoch 23/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 4.8622e-05 - val_loss: 3.6284e-05
# Epoch 24/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.8560e-05 - val_loss: 3.5990e-05
# Epoch 25/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.9961e-05 - val_loss: 3.4148e-05
# Epoch 26/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8933e-05 - val_loss: 3.6916e-05
# Epoch 27/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8253e-05 - val_loss: 3.1853e-05
# Epoch 28/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.0664e-05 - val_loss: 3.4452e-05
# Epoch 29/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.7720e-05 - val_loss: 3.5294e-05
# Epoch 30/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8345e-05 - val_loss: 3.8249e-05
# Epoch 31/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8810e-05 - val_loss: 3.5962e-05
# Epoch 32/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.7917e-05 - val_loss: 3.9659e-05
# Epoch 33/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8073e-05 - val_loss: 3.9371e-05
# Epoch 34/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.0793e-05 - val_loss: 3.8374e-05
# Epoch 35/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.9452e-05 - val_loss: 3.9378e-05
# Epoch 36/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.8042e-05 - val_loss: 4.1188e-05
# Epoch 37/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.8713e-05 - val_loss: 4.4647e-05
# Epoch 38/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7708e-05 - val_loss: 3.7634e-05
# Epoch 39/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7781e-05 - val_loss: 3.8139e-05
# Epoch 40/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7936e-05 - val_loss: 3.8411e-05
# Epoch 41/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8780e-05 - val_loss: 3.5867e-05
# Epoch 42/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7141e-05 - val_loss: 3.8449e-05
# Epoch 43/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7094e-05 - val_loss: 4.3332e-05
# Epoch 44/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8092e-05 - val_loss: 4.1019e-05
# Epoch 45/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8585e-05 - val_loss: 4.0676e-05
# Epoch 46/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.7210e-05 - val_loss: 3.8360e-05
# Epoch 47/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.8631e-05 - val_loss: 4.2039e-05
# Epoch 48/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.9052e-05 - val_loss: 4.1558e-05
# Epoch 49/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 4.8034e-05 - val_loss: 4.2340e-05
# Epoch 50/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 4.6854e-05 - val_loss: 4.5784e-05
# Epoch 1/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 7.1364e-05 - val_loss: 3.7226e-05
# Epoch 2/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.6795e-05 - val_loss: 3.6913e-05
# Epoch 3/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.6617e-05 - val_loss: 3.6672e-05
# Epoch 4/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.4067e-05 - val_loss: 4.0802e-05
# Epoch 5/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.5870e-05 - val_loss: 4.0348e-05
# Epoch 6/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.4899e-05 - val_loss: 4.6945e-05
# Epoch 7/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.7362e-05 - val_loss: 4.1474e-05
# Epoch 8/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 6.3248e-05 - val_loss: 4.0176e-05
# Epoch 9/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.7496e-05 - val_loss: 3.9552e-05
# Epoch 10/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.4713e-05 - val_loss: 4.4908e-05
# Epoch 11/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.5092e-05 - val_loss: 5.0700e-05
# Epoch 12/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.5961e-05 - val_loss: 4.4768e-05
# Epoch 13/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.3232e-05 - val_loss: 4.9852e-05
# Epoch 14/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.5699e-05 - val_loss: 4.6193e-05
# Epoch 15/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.5762e-05 - val_loss: 4.5790e-05
# Epoch 16/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.4975e-05 - val_loss: 5.6122e-05
# Epoch 17/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.5420e-05 - val_loss: 6.4106e-05
# Epoch 18/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 6.3392e-05 - val_loss: 5.4988e-05
# Epoch 19/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 6.3881e-05 - val_loss: 5.6596e-05
# Epoch 20/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.4992e-05 - val_loss: 5.9899e-05
# Epoch 21/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.2860e-05 - val_loss: 6.3457e-05
# Epoch 22/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.1090e-05 - val_loss: 5.8929e-05
# Epoch 23/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.2228e-05 - val_loss: 6.4575e-05
# Epoch 24/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.1405e-05 - val_loss: 6.0706e-05
# Epoch 25/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.2696e-05 - val_loss: 6.3005e-05
# Epoch 26/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.3173e-05 - val_loss: 6.1172e-05
# Epoch 27/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.4456e-05 - val_loss: 7.1502e-05
# Epoch 28/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.4785e-05 - val_loss: 7.1285e-05
# Epoch 29/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 6.2544e-05 - val_loss: 6.4525e-05
# Epoch 30/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.2460e-05 - val_loss: 6.3751e-05
# Epoch 31/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.3453e-05 - val_loss: 5.9630e-05
# Epoch 32/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.4456e-05 - val_loss: 6.4530e-05
# Epoch 33/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.1773e-05 - val_loss: 7.2598e-05
# Epoch 34/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.3502e-05 - val_loss: 7.1278e-05
# Epoch 35/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 6.2940e-05 - val_loss: 6.3394e-05
# Epoch 36/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.5054e-05 - val_loss: 6.6004e-05
# Epoch 37/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 6.1936e-05 - val_loss: 6.6609e-05
# Epoch 38/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.1531e-05 - val_loss: 6.7142e-05
# Epoch 39/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.3967e-05 - val_loss: 6.6761e-05
# Epoch 40/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.3585e-05 - val_loss: 6.7345e-05
# Epoch 41/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 6.3683e-05 - val_loss: 5.7442e-05
# Epoch 42/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.3366e-05 - val_loss: 5.8993e-05
# Epoch 43/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.2652e-05 - val_loss: 6.4977e-05
# Epoch 44/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 6.2422e-05 - val_loss: 6.3739e-05
# Epoch 45/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.0938e-05 - val_loss: 6.8721e-05
# Epoch 46/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.1630e-05 - val_loss: 7.4380e-05
# Epoch 47/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.1935e-05 - val_loss: 6.8019e-05
# Epoch 48/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 6.2989e-05 - val_loss: 8.9230e-05
# Epoch 49/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.5012e-05 - val_loss: 6.5203e-05
# Epoch 50/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 6.1675e-05 - val_loss: 7.2360e-05
# Epoch 1/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.4773e-04 - val_loss: 2.4723e-05
# Epoch 2/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.5214e-05 - val_loss: 2.3236e-05
# Epoch 3/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 6.4261e-05 - val_loss: 2.3282e-05
# Epoch 4/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.3274e-05 - val_loss: 2.4484e-05
# Epoch 5/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.9633e-05 - val_loss: 2.5211e-05
# Epoch 6/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.6320e-05 - val_loss: 2.5992e-05
# Epoch 7/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.1505e-05 - val_loss: 3.2569e-05
# Epoch 8/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.7364e-05 - val_loss: 3.1040e-05
# Epoch 9/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.5220e-05 - val_loss: 3.1984e-05
# Epoch 10/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.9219e-05 - val_loss: 3.4489e-05
# Epoch 11/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.6838e-05 - val_loss: 3.9966e-05
# Epoch 12/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.8532e-05 - val_loss: 5.2307e-05
# Epoch 13/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.5911e-05 - val_loss: 3.8230e-05
# Epoch 14/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.7571e-05 - val_loss: 4.1077e-05
# Epoch 15/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.7867e-05 - val_loss: 4.6861e-05
# Epoch 16/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.8271e-05 - val_loss: 4.2285e-05
# Epoch 17/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.7770e-05 - val_loss: 4.5072e-05
# Epoch 18/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.5648e-05 - val_loss: 5.3063e-05
# Epoch 19/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.1109e-05 - val_loss: 6.8629e-05
# Epoch 20/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.8677e-05 - val_loss: 7.3523e-05
# Epoch 21/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.5726e-05 - val_loss: 6.8064e-05
# Epoch 22/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.7104e-05 - val_loss: 7.1060e-05
# Epoch 23/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.6684e-05 - val_loss: 7.5102e-05
# Epoch 24/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.7518e-05 - val_loss: 7.8375e-05
# Epoch 25/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.3713e-05 - val_loss: 7.4349e-05
# Epoch 26/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.5283e-05 - val_loss: 9.2658e-05
# Epoch 27/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.4772e-05 - val_loss: 9.2433e-05
# Epoch 28/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.0434e-05 - val_loss: 1.0462e-04
# Epoch 29/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.5655e-05 - val_loss: 1.0738e-04
# Epoch 30/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.4886e-05 - val_loss: 1.1579e-04
# Epoch 31/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.7252e-05 - val_loss: 1.1983e-04
# Epoch 32/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.6485e-05 - val_loss: 1.2585e-04
# Epoch 33/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.7756e-05 - val_loss: 1.1951e-04
# Epoch 34/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.7286e-05 - val_loss: 1.3745e-04
# Epoch 35/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.3748e-05 - val_loss: 1.3460e-04
# Epoch 36/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.2610e-05 - val_loss: 1.2905e-04
# Epoch 37/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.6046e-05 - val_loss: 1.3686e-04
# Epoch 38/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.4257e-05 - val_loss: 1.2329e-04
# Epoch 39/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.4109e-05 - val_loss: 1.0448e-04
# Epoch 40/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.5439e-05 - val_loss: 1.1088e-04
# Epoch 41/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 6.1386e-05 - val_loss: 1.1946e-04
# Epoch 42/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.3427e-05 - val_loss: 9.9551e-05
# Epoch 43/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.5282e-05 - val_loss: 1.1480e-04
# Epoch 44/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.3647e-05 - val_loss: 1.0307e-04
# Epoch 45/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.3603e-05 - val_loss: 1.0494e-04
# Epoch 46/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.6819e-05 - val_loss: 1.3082e-04
# Epoch 47/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.2833e-05 - val_loss: 1.1395e-04
# Epoch 48/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.3862e-05 - val_loss: 1.1738e-04
# Epoch 49/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 5.2820e-05 - val_loss: 1.0501e-04
# Epoch 50/50
# 2183/2183 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 5.3352e-05 - val_loss: 1.1241e-04

# %% [markdown]
# ### Testing the model

# %%
predictions = {}

for symbol in symbols:
    X_test = create_LSTM_input(market_test.coins[symbol].features)
    predictions[symbol] = model.predict(X_test)
# Out:
# 1090/1090 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 1090/1090 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 1090/1090 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1090/1090 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1090/1090 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 1090/1090 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 1090/1090 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step
# 1090/1090 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# 1090/1090 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step

# %%
long_threshold = 0.5
close_long_threshold = 0

short_threshold = -0.5
close_short_threshold = 0

leverage = 2

results = {}

for symbol in symbols:
    market_test.reset()
    scaler = StandardScaler()
    prediction = scaler.fit_transform(predictions[symbol])

    test_time = market_test.coins[symbol].features[-len(X_test):].index

    account_values = np.zeros((len(test_time)))
    for index, time in enumerate(test_time):
        price = market_test.prices.loc[time, symbol]

        if market_test.coins[symbol].position == "Closed" and prediction[index] > long_threshold:
            qty = market_test.cash * leverage / price
            market_test.trade(
                symbol=symbol,
                action="long",
                quantity=qty,
                price=price,
                time=time
            )

        if market_test.coins[symbol].position == "Long" and prediction[index] < close_long_threshold:
            qty = market_test.assets[symbol]
            market_test.trade(
                symbol=symbol,
                action="close",
                quantity=qty,
                price=price,
                time=time
            )

        if market_test.coins[symbol].position == "Closed" and prediction[index] < short_threshold:
            qty = market_test.cash * leverage / price
            market_test.trade(
                symbol=symbol,
                action="long",
                quantity=qty,
                price=price,
                time=time
            )

        if market_test.coins[symbol].position == "Short" and prediction[index] > close_short_threshold:
            qty = market_test.assets[symbol]
            market_test.trade(
                symbol=symbol,
                action="close",
                quantity=qty,
                price=price,
                time=time
            )

        if market_test.get_margin_ratio(time) >= 1:
            print(f"{symbol} liquidated")
            continue

        account_values[index] = market_test.cash + \
            market_test.assets[symbol] * market_test.prices.loc[time, symbol] - \
                market_test.coins[symbol].entry_cost

    if market_test.coins[symbol].position == "Long":
        price = market_test.prices.loc[time, symbol]
        qty = market_test.assets[symbol]
        market_test.trade(symbol, "close", qty, price, time)
    account_values[index] = market_test.cash + \
        market_test.assets[symbol] * market_test.prices.loc[time, symbol] - \
            market_test.coins[symbol].entry_cost

    results[symbol] = account_values

# %%
for symbol in symbols:
    buy_and_hold = market_test.prices.loc[test_time,symbol] / market_test.prices.loc[test_time[0],symbol]
    strategy_pl = results[symbol] / results[symbol][0]
    score = strategy_pl / buy_and_hold

    plt.plot(
        test_time,
        score,
        label = symbol
    )

plt.axhline(y=1, linestyle='--')

plt.legend()
plt.show()

# %% [markdown]
# # To Do
# - test with simple strategy
#     - only one asset in a portfolio
#     - test which asset performs the best
#     - check G/L distribution at different time
#     - see if can mitigate loss by creating a portfolio
# - Model volatility and trade option
# - Apply the same PCA and MinMaxScaler to train, val and test

# %% [markdown]
# ## Backtesting

# %% [markdown]
# ## Results

# %% [markdown]
# ## Ad hoc
